# %%
import cv2 #pip install opencv-python1

# %%
from deepface import DeepFace ##pip install deepface

# %%
img =cv2.imread('happy_boy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #it is BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 20ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  8.44it/s]
# 1/1 [==============================] - 0s 311ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  3.40it/s]
# 1/1 [==============================] - 0s 309ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  3.09it/s]
# 1/1 [==============================] - 1s 505ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.76it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 1.5710355447660397e-12,
#   'disgust': 1.2463945294965633e-24,
#   'fear': 4.860035707210386e-08,
#   'happy': 100.0,
#   'sad': 2.001608878643424e-08,
#   'surprise': 1.0971672355364337e-09,
#   'neutral': 8.081876314014469e-10},
#  'dominant_emotion': 'happy',
#  'region': {'x': 264, 'y': 34, 'w': 93, 'h': 93},
#  'age': 14,
#  'gender': 'Man',
#  'race': {'asian': 0.05942848055329687,
#   'indian': 0.011094388041022857,
#   'black': 0.00030719910706939244,
#   'white': 88.32194665932019,
#   'middle eastern': 2.5672753607958985,
#   'latino hispanic': 9.039951448434763},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
# we Are Trying To draw a Rectangle across the face
gray =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)
#Draw a rectangle around the faces 
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font =cv2.FONT_HERSHEY_SIMPLEX
    #Use putText() method for 
    #insering text on video
cv2.putText(img, 
            predictions['dominant_emotion'],
            (0,50),
            font, 1, 
            (0,0,255),
            2,
            cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img =cv2.imread('sad_women.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 15ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  6.95it/s]
# 1/1 [==============================] - 0s 290ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  3.34it/s]
# 1/1 [==============================] - 0s 276ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  3.25it/s]
# 1/1 [==============================] - 0s 290ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.30it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.07678339273829547,
#   'disgust': 5.927251732280804e-09,
#   'fear': 1.6007114156232576,
#   'happy': 1.619249536826578e-05,
#   'sad': 19.426923164496046,
#   'surprise': 0.2061694381854608,
#   'neutral': 78.68939296133603},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 55, 'y': 3, 'w': 300, 'h': 300},
#  'age': 29,
#  'gender': 'Woman',
#  'race': {'asian': 0.08213772274215844,
#   'indian': 0.044825024565120095,
#   'black': 0.007228212646244821,
#   'white': 89.45908672105232,
#   'middle eastern': 3.658391844225902,
#   'latino hispanic': 6.748326063355677},
#  'dominant_race': 'white'}

# %%
img =cv2.imread('fear_man.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|                                                                           | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 20ms/step
# Action: age:  25%|█████████████████▊                                                     | 1/4 [00:00<00:00,  7.20it/s]
# 1/1 [==============================] - 0s 280ms/step
# Action: gender:  50%|██████████████████████████████████                                  | 2/4 [00:00<00:00,  3.57it/s]
# 1/1 [==============================] - 0s 311ms/step
# Action: race:  75%|████████████████████████████████████████████████████▌                 | 3/4 [00:00<00:00,  3.19it/s]
# 1/1 [==============================] - 0s 349ms/step
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.17it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 69.40274834632874,
#   'disgust': 0.00011716766721292515,
#   'fear': 28.27434539794922,
#   'happy': 0.04004637885373086,
#   'sad': 1.556899305433035,
#   'surprise': 0.011642385652521625,
#   'neutral': 0.7142059039324522},
#  'dominant_emotion': 'angry',
#  'region': {'x': 196, 'y': 93, 'w': 129, 'h': 129},
#  'age': 28,
#  'gender': 'Man',
#  'race': {'asian': 0.002389413305704857,
#   'indian': 0.1942215369645103,
#   'black': 0.00028940661462284315,
#   'white': 48.06894040929561,
#   'middle eastern': 46.209156061310296,
#   'latino hispanic': 5.525008130074516},
#  'dominant_race': 'white'}

# %%
#Real Time Video Demo For Face Emotion Recognition
import cv2 #pip install opencv - pyhton 
#pip install opencv-python fullpackage
from deepface import DeepFace #pip install deepface

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)
#check if the web cam is opened correctly
if not cap.isOpened():
    cap =cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot Open Webcam")
    
while True:
    ret,frame=cap.read()
    result = DeepFace.analyze(frame, actions = ['Emotion'])
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
    faces= faceCascade.detectMultiScale(gray,1.1,4)
    
    #Draw a Rectangle Around The Faces
    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255, 0), 2)
        
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    #use putText()method for 
    #interesting text on video
    
    cv2.putText(frame,
               result['dominant_emotion'],
               (50,50),
               font, 3,
               (0,0,255),
               2,
               cv2.LINE_4)
    cv2.imshow('Demo video', frame)
    
    if cv2.waitKey(2) & 0xFF == ord ('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
#   File "C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4576\807484811.py", line 38
#     cv2.imshow('Demo video', frame')
#                                     ^
# SyntaxError: EOL while scanning string literal
